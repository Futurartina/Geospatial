# %%
import pandas as pd
from pymongo import MongoClient
client = MongoClient("localhost:27017")

# %%
client.list_database_names()
# Lists all the databases in my Mongo.
# Out:
# ['Ironhack', 'admin', 'config', 'local']

# %%
db = client["Ironhack"]
# Looks for the database called "Ironhack".

# %%
db.list_collection_names()
# Lists all the collections inside the "Ironhack" database.
# Out:
# ['nyrest', 'myneigh', 'Companies']

# %%
collection = db.get_collection("Companies")
# Accesses the collection called "Companies".

# %%
total_count = collection.count_documents({})
total_count
# Counts the number of rows in the collection.
# Out:
# 18801

# %%
unique_values = collection.distinct('category_code')

for i in unique_values:
    print(i)
# Prints the unique values of 'category_code'.
# Out:
# None
# advertising
# analytics
# automotive
# biotech
# cleantech
# consulting
# design
# ecommerce
# education
# enterprise
# fashion
# finance
# games_video
# government
# hardware
# health
# hospitality
# legal
# local
# manufacturing
# medical
# messaging
# mobile
# music
# nanotech
# network_hosting
# news
# nonprofit
# other
# photo_video
# public_relations
# real_estate
# search
# security
# semiconductor
# social
# software
# sports
# transportation
# travel
# web

# %%
values_to_match = ['analytics', 'biotech', 'cleantech', 'games_video', 'hardware', 'nanotech', 'network_hosting', 'software', 'web']
condition_1 = {'category_code':{'$in': values_to_match}}
# Defines condition_1 with companies related to the tech world.

# %%
document_count = collection.count_documents(condition_1)
document_count
# Counts all the rows after filtering with condition_1.
# Out:
# 9349

# %%
unique_values_1 = collection.distinct('total_money_raised')

for i in unique_values_1:
    print(i)
# Prints all the unique values for column "total_money_raised".
# Out:
# $0
# $1.01M
# $1.02M
# $1.03M
# $1.04M
# $1.05M
# $1.06B
# $1.08M
# $1.09M
# $1.11M
# $1.13M
# $1.14M
# $1.15B
# $1.15M
# $1.16B
# $1.17M
# $1.19M
# $1.1B
# $1.1M
# $1.21M
# $1.23M
# $1.25M
# $1.27M
# $1.2B
# $1.2M
# $1.31M
# $1.32M
# $1.33M
# $1.35M
# $1.36M
# $1.3M
# $1.42M
# $1.44M
# $1.45M
# $1.46M
# $1.4M
# $1.51M
# $1.53M
# $1.55M
# $1.56M
# $1.57M
# $1.58M
# $1.5M
# $1.61M
# $1.62M
# $1.63M
# $1.65M
# $1.66M
# $1.67M
# $1.68M
# $1.69M
# $1.6M
# $1.71M
# $1.72M
# $1.73M
# $1.75M
# $1.77B
# $1.77M
# $1.7M
# $1.81M
# $1.82M
# $1.83M
# $1.84M
# $1.8M
# $1.92M
# $1.94M
# $1.95M
# $1.96M
# $1.97M
# $1.98M
# $1.99M
# $1.9M
# $10.1M
# $10.2M
# $10.3M
# $10.4M
# $10.5M
# $10.6M
# $10.7M
# $10.8M
# $10.9M
# $100M
# $100k
# $101M
# $101k
# $102M
# $103M
# $104M
# $105M
# $105k
# $106M
# $107M
# $108M
# $109M
# $10M
# $10k
# $11.1M
# $11.2M
# $11.3M
# $11.4M
# $11.5M
# $11.6M
# $11.7M
# $11.8M
# $11.9M
# $110M
# $110k
# $111M
# $112M
# $113M
# $114M
# $115M
# $115k
# $116M
# $117M
# $118M
# $119M
# $11M
# $12.1M
# $12.2M
# $12.3M
# $12.4M
# $12.5M
# $12.5k
# $12.6M
# $12.7M
# $12.8M
# €10.1M
# €10.3M
# €100k
# €10M
# €10k
# €11.1M
# €11.5M
# €121M
# €12M
# €130k
# €141k
# €146k
# €14M
# €15.9M
# €150k
# €16k
# €180k
# €190k
# €19M
# €1M
# €2.15M
# €2.5M
# €2.6M
# €2.75M
# €2.7M
# €20.7M
# €200k
# €203k
# €21.3M
# €215k
# €22.7M
# €225k
# €23.4M
# €23M
# €250k
# €25M
# €25k
# €26.2M
# €26M
# €2M
# €3.04M
# €3.1M
# €3.3M
# €3.5M
# €3.66M
# €3.7M
# €3.9M
# €30.9M
# €300k
# €30M
# €334M
# €35M
# €35k
# €360k
# €36M
# €3M
# €4.25M
# €400k
# €41M
# €420M
# €424k
# €44M
# €450k
# €4M
# €5.4M
# €5.5M
# €5.7M
# €500k
# €50k
# €550k
# €583k
# €589k
# €59M
# €5M
# €6.5M
# €600k
# €640k
# €650k
# €685k
# €690k
# €6M
# €7.44M
# €700k
# €70k
# €73M
# €750k
# €77.1k
# €7M
# €8.2M
# €8.3M
# €8.97M
# €800k
# €850k
# €87M
# €9.46M
# €900k
# €91k
# €99M
# €9M

# %%
condition_2 = {"total_money_raised":{"$regex": "M$|B$", "$options": "i"}}
# Defines condition_2 based on "total_money_raised" higher than 1M.

# %%
len(list(collection.find({"total_money_raised":{"$regex": "M$|B$"}})))
# Counts all the rows after filtering the total amount raised higher than 1M.
# Out:
# 4042

# %%
projection = {"_id": 0}
final_filter = list(collection.find({"$and":[condition_1, condition_2]}, projection))
# Defines a final_filter cobining condition_1 and condition_2.

# %%
len(final_filter)
# Prints the length of the final_filter.
# Out:
# 2292

# %%
df_1 = pd.DataFrame(final_filter)
df_1
# Prints the dataframe after the last filter.
# Out:
#                    name          permalink  \
# 0              Wetpaint               abc2
# 1                  Geni               geni
# 2           StumbleUpon        stumbleupon
# 3                Gizmoz             gizmoz
# 4                  Lala               lala
# ...                 ...                ...
# 2287   Chestnut Medical   chestnut-medical
# 2288           iGuiders           iguiders
# 2289  SolarPower Israel  solarpower-israel
# 2290           Purfresh           purfresh
# 2291    InSound Medical    insound-medical
#
#                                          crunchbase_url  \
# 0            http://www.crunchbase.com/company/wetpaint
# 1                http://www.crunchbase.com/company/geni
# 2         http://www.crunchbase.com/company/stumbleupon
# 3              http://www.crunchbase.com/company/gizmoz
# 4                http://www.crunchbase.com/company/lala
# ...                                                 ...
# 2287  http://www.crunchbase.com/company/chestnut-med...
# 2288         http://www.crunchbase.com/company/iguiders
# 2289  http://www.crunchbase.com/company/solarpower-i...
# 2290         http://www.crunchbase.com/company/purfresh
# 2291  http://www.crunchbase.com/company/insound-medical
#
#                         homepage_url                          blog_url  \
# 0            http://wetpaint-inc.com       http://digitalquarters.net/
# 1                http://www.geni.com              http://blog.geni.com
# 2         http://www.stumbleupon.com   http://www.stumbleupon.com/blog
# 3                  http://gizmoz.com
# 4                http://www.lala.com         http://www.lala.com/#blog
# ...                              ...                               ...
# 2287  http://www.chestnutmedical.com
# 2288         http://www.iguiders.com
# 2289     http://www.solarpower.co.il
# 2290         http://www.purfresh.com  http://info.purfresh.com/PurTalk
# 2291   http://www.insoundmedical.com
#
#                          blog_feed_url twitter_username category_code  \
# 0     http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1       http://blog.geni.com/index.rdf             geni           web
# 2                                           stumbleupon           web
# 3                                                  None           web
# 4            http://www.lala.com/#blog             None   games_video
# ...                                ...              ...           ...
# 2287                                                          biotech
# 2288                                           iGuiders           web
# 2289                                                        cleantech
# 2290                                       Purfresh_Inc     cleantech
# 2291                                                          biotech
#
#       number_of_employees  founded_year  ...  \
# 0                    47.0        2005.0  ...
# 1                    18.0        2006.0  ...
# 2                     NaN        2002.0  ...
# 3                     NaN        2003.0  ...
# 4                     NaN           NaN  ...
# ...                   ...           ...  ...
# 2287                  NaN           NaN  ...
# 2288                  5.0        2008.0  ...
# 2289                  NaN           NaN  ...
# 2290                  NaN        1996.0  ...
# 2291                  NaN           NaN  ...
#
#                                                 offices  \
# 0     [{'description': '', 'address1': '710 - 2nd Av...
# 1     [{'description': 'Headquarters', 'address1': '...
# 2     [{'description': '', 'address1': '', 'address2...
# 3     [{'description': None, 'address1': None, 'addr...
# 4     [{'description': 'Lala Headquarters', 'address...
# ...                                                 ...
# 2287  [{'description': '', 'address1': '173 Jefferso...
# 2288  [{'description': '', 'address1': '23811 Chagri...
# 2289  [{'description': '', 'address1': 'Yevulim Comp...
# 2290  [{'description': 'HQ', 'address1': '1350 Willo...
# 2291  [{'description': '', 'address1': '39660 Eureka...
#
#                                              milestones  \
# 0     [{'id': 5869, 'description': 'Wetpaint named i...
# 1     [{'id': 15460, 'description': 'Announced hire ...
# 2     [{'id': 3103, 'description': 'Spin-out from Eb...
# 3                                                    []
# 4     [{'id': 5065, 'description': 'Apple acquires L...
# ...                                                 ...
# 2287                                                 []
# 2288                                                 []
# 2289                                                 []
# 2290                                                 []
# 2291                                                 []
#
#                                            video_embeds  \
# 0                                                    []
# 1     [{'embed_code': '<object width="425" height="3...
# 2     [{'embed_code': '<embed src="http://blip.tv/pl...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2287                                                 []
# 2288  [{'embed_code': '<embed src="http://blip.tv/pl...
# 2289                                                 []
# 2290                                                 []
# 2291                                                 []
#
#                                             screenshots  \
# 0     [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                    []
# 2     [{'available_sizes': [[[150, 72], 'assets/imag...
# 3                                                    []
# 4     [{'available_sizes': [[[150, 103], 'assets/ima...
# ...                                                 ...
# 2287  [{'available_sizes': [[[150, 98], 'assets/imag...
# 2288  [{'available_sizes': [[[150, 90], 'assets/imag...
# 2289  [{'available_sizes': [[[150, 102], 'assets/ima...
# 2290  [{'available_sizes': [[[150, 91], 'assets/imag...
# 2291  [{'available_sizes': [[[150, 91], 'assets/imag...
#
#                                          external_links partners  \
# 0     [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                    []       []
# 2     [{'external_url': 'http://www.facebook.com/Stu...       []
# 3                                                    []       []
# 4                                                    []       []
# ...                                                 ...      ...
# 2287                                                 []       []
# 2288                                                 []       []
# 2289                                                 []       []
# 2290                                                 []       []
# 2291                                                 []       []
#
#      deadpooled_month deadpooled_day deadpooled_url   ipo
# 0                 NaN            NaN            NaN   NaN
# 1                 NaN            NaN            NaN   NaN
# 2                 NaN            NaN            NaN   NaN
# 3                 NaN            NaN            NaN   NaN
# 4                 NaN            NaN            NaN   NaN
# ...               ...            ...            ...   ...
# 2287              NaN            NaN           None  None
# 2288              NaN            NaN           None  None
# 2289              NaN            NaN           None  None
# 2290              NaN            NaN           None  None
# 2291              NaN            NaN           None  None
#
# [2292 rows x 41 columns]

# %%
country_counts = {}
for doc in final_filter:
    if "offices" in doc and len(doc["offices"]) > 0 and "country_code" in doc["offices"][0]:
        country_code = doc["offices"][0]["country_code"]
        if country_code in country_counts:
            country_counts[country_code] += 1
        else:
            country_counts[country_code] = 1
df_country_counts = pd.DataFrame(list(country_counts.items()), columns=["Country Code", "Count"])
df_country_counts = df_country_counts.sort_values(by="Count", ascending=False)
df_country_counts
# Counts the appearance of each country in the whole dataset.
# Out:
#    Country Code  Count
# 0           USA   1688
# 1           GBR    102
# 8           CAN     58
# 3           ISR     55
# 6           FRA     51
# 16          CHN     37
# 4           DEU     33
# 11          IND     22
# 7           CHE     14
# 22          SWE     14
# 18          IRL     12
# 5           NLD     10
# 9           AUS      9
# 15          DNK      9
# 26          ESP      8
# 23          FIN      7
# 21          NOR      6
# 13          SGP      6
# 12          JPN      6
# 28          AUT      5
# 14          KOR      5
# 25          BEL      5
# 29          ITA      3
# 36          TWN      2
# 31          RUS      2
# 27          ARG      2
# 17          PRT      2
# 10          MYS      2
# 33          NZL      2
# 37          HKG      1
# 38          CZE      1
# 34          EGY      1
# 39          MEX      1
# 35          PAK      1
# 20          JOR      1
# 32          HUN      1
# 30          ISL      1
# 24          ROM      1
# 19          ZAF      1
# 2           LUX      1
# 40          ARE      1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top_10_countries = df_country_counts.head(10)

plt.bar(top_10_countries["Country Code"], top_10_countries["Count"])
plt.title("Top 10 countries in Tech")
plt.savefig('Top 10 countries in Tech.jpg', format='jpg')
plt.show()
# Shows the top 10 countries (with more appearance in the dataset) in a bar plot.

# %%
df_1['City'] = df_1['offices'].apply(lambda x: x[0]['city'] if (x and len(x) > 0 and 'city' in x[0]) else None)
df_1['Country Code'] = df_1['offices'].apply(lambda x: x[0]['country_code'] if (x and len(x) > 0 and 'country_code' in x[0]) else None)
df_1
# Adds new columns named "City" and "Country Code" at the end of the dataframe with the information related to each company.
# Out:
#                    name          permalink  \
# 0              Wetpaint               abc2
# 1                  Geni               geni
# 2           StumbleUpon        stumbleupon
# 3                Gizmoz             gizmoz
# 4                  Lala               lala
# ...                 ...                ...
# 2287   Chestnut Medical   chestnut-medical
# 2288           iGuiders           iguiders
# 2289  SolarPower Israel  solarpower-israel
# 2290           Purfresh           purfresh
# 2291    InSound Medical    insound-medical
#
#                                          crunchbase_url  \
# 0            http://www.crunchbase.com/company/wetpaint
# 1                http://www.crunchbase.com/company/geni
# 2         http://www.crunchbase.com/company/stumbleupon
# 3              http://www.crunchbase.com/company/gizmoz
# 4                http://www.crunchbase.com/company/lala
# ...                                                 ...
# 2287  http://www.crunchbase.com/company/chestnut-med...
# 2288         http://www.crunchbase.com/company/iguiders
# 2289  http://www.crunchbase.com/company/solarpower-i...
# 2290         http://www.crunchbase.com/company/purfresh
# 2291  http://www.crunchbase.com/company/insound-medical
#
#                         homepage_url                          blog_url  \
# 0            http://wetpaint-inc.com       http://digitalquarters.net/
# 1                http://www.geni.com              http://blog.geni.com
# 2         http://www.stumbleupon.com   http://www.stumbleupon.com/blog
# 3                  http://gizmoz.com
# 4                http://www.lala.com         http://www.lala.com/#blog
# ...                              ...                               ...
# 2287  http://www.chestnutmedical.com
# 2288         http://www.iguiders.com
# 2289     http://www.solarpower.co.il
# 2290         http://www.purfresh.com  http://info.purfresh.com/PurTalk
# 2291   http://www.insoundmedical.com
#
#                          blog_feed_url twitter_username category_code  \
# 0     http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1       http://blog.geni.com/index.rdf             geni           web
# 2                                           stumbleupon           web
# 3                                                  None           web
# 4            http://www.lala.com/#blog             None   games_video
# ...                                ...              ...           ...
# 2287                                                          biotech
# 2288                                           iGuiders           web
# 2289                                                        cleantech
# 2290                                       Purfresh_Inc     cleantech
# 2291                                                          biotech
#
#       number_of_employees  founded_year  ...  \
# 0                    47.0        2005.0  ...
# 1                    18.0        2006.0  ...
# 2                     NaN        2002.0  ...
# 3                     NaN        2003.0  ...
# 4                     NaN           NaN  ...
# ...                   ...           ...  ...
# 2287                  NaN           NaN  ...
# 2288                  5.0        2008.0  ...
# 2289                  NaN           NaN  ...
# 2290                  NaN        1996.0  ...
# 2291                  NaN           NaN  ...
#
#                                            video_embeds  \
# 0                                                    []
# 1     [{'embed_code': '<object width="425" height="3...
# 2     [{'embed_code': '<embed src="http://blip.tv/pl...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 2287                                                 []
# 2288  [{'embed_code': '<embed src="http://blip.tv/pl...
# 2289                                                 []
# 2290                                                 []
# 2291                                                 []
#
#                                             screenshots  \
# 0     [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                    []
# 2     [{'available_sizes': [[[150, 72], 'assets/imag...
# 3                                                    []
# 4     [{'available_sizes': [[[150, 103], 'assets/ima...
# ...                                                 ...
# 2287  [{'available_sizes': [[[150, 98], 'assets/imag...
# 2288  [{'available_sizes': [[[150, 90], 'assets/imag...
# 2289  [{'available_sizes': [[[150, 102], 'assets/ima...
# 2290  [{'available_sizes': [[[150, 91], 'assets/imag...
# 2291  [{'available_sizes': [[[150, 91], 'assets/imag...
#
#                                          external_links partners  \
# 0     [{'external_url': 'http://www.geekwire.com/201...       []
# 1                                                    []       []
# 2     [{'external_url': 'http://www.facebook.com/Stu...       []
# 3                                                    []       []
# 4                                                    []       []
# ...                                                 ...      ...
# 2287                                                 []       []
# 2288                                                 []       []
# 2289                                                 []       []
# 2290                                                 []       []
# 2291                                                 []       []
#
#      deadpooled_month deadpooled_day deadpooled_url   ipo            City  \
# 0                 NaN            NaN            NaN   NaN         Seattle
# 1                 NaN            NaN           None  None  West Hollywood
# 2                 NaN            NaN           None  None   San Francisco
# 3                 NaN            NaN           None  None      Menlo Park
# 4                 NaN            NaN           None  None       Palo Alto
# ...               ...            ...            ...   ...             ...
# 2287              NaN            NaN           None  None      Menlo Park
# 2288              NaN            NaN           None  None       Beachwood
# 2289              NaN            NaN           None  None
# 2290              NaN            NaN           None  None      Menlo Park
# 2291              NaN            NaN           None  None          Newark
#
#      Country Code
# 0             USA
# 1             USA
# 2             USA
# 3             USA
# 4             USA
# ...           ...
# 2287          USA
# 2288          USA
# 2289          ISR
# 2290          USA
# 2291          USA
#
# [2292 rows x 43 columns]

# %%
cities_in_usa = df_1[df_1["Country Code"] == "USA"]
city_counts = cities_in_usa["City"].value_counts().reset_index()
city_counts.columns = ["City", "Count"]
city_counts = pd.DataFrame(city_counts)
city_counts 
# Counts the repetition of the cities in USA.
# Out:
#               City  Count
# 0    San Francisco    184
# 1         New York    132
# 2          Seattle     55
# 3    Mountain View     55
# 4        Palo Alto     52
# ..             ...    ...
# 380        Ephrata      1
# 381         Dayton      1
# 382         Dulles      1
# 383     Charleston      1
# 384         Skokie      1
#
# [385 rows x 2 columns]

# %%
top_10_cities_usa = city_counts.head(10)
plt.figure(figsize=(6, 8)) 
plt.bar(top_10_cities_usa["City"], top_10_cities_usa["Count"])

plt.xticks(rotation=45) 
plt.title("Top 10 cities in Tech in USA")
plt.savefig('Top 10 cities in Tech in USA.jpg', format='jpg')
plt.show()
# Shows the top 10 cities in USA (with more appearance in the dataset) in a bar plot.

# %%
df_1['Zip Code'] = df_1['offices'].apply(lambda x: x[0]['zip_code'] if (x and len(x) > 0 and 'zip_code' in x[0]) else None)
df_1
# Adds new columns named "City" and "Country Code" at the end of the dataframe with the information related to each company.
# Out:
#                    name          permalink  \
# 0              Wetpaint               abc2
# 1                  Geni               geni
# 2           StumbleUpon        stumbleupon
# 3                Gizmoz             gizmoz
# 4                  Lala               lala
# ...                 ...                ...
# 2287   Chestnut Medical   chestnut-medical
# 2288           iGuiders           iguiders
# 2289  SolarPower Israel  solarpower-israel
# 2290           Purfresh           purfresh
# 2291    InSound Medical    insound-medical
#
#                                          crunchbase_url  \
# 0            http://www.crunchbase.com/company/wetpaint
# 1                http://www.crunchbase.com/company/geni
# 2         http://www.crunchbase.com/company/stumbleupon
# 3              http://www.crunchbase.com/company/gizmoz
# 4                http://www.crunchbase.com/company/lala
# ...                                                 ...
# 2287  http://www.crunchbase.com/company/chestnut-med...
# 2288         http://www.crunchbase.com/company/iguiders
# 2289  http://www.crunchbase.com/company/solarpower-i...
# 2290         http://www.crunchbase.com/company/purfresh
# 2291  http://www.crunchbase.com/company/insound-medical
#
#                         homepage_url                          blog_url  \
# 0            http://wetpaint-inc.com       http://digitalquarters.net/
# 1                http://www.geni.com              http://blog.geni.com
# 2         http://www.stumbleupon.com   http://www.stumbleupon.com/blog
# 3                  http://gizmoz.com
# 4                http://www.lala.com         http://www.lala.com/#blog
# ...                              ...                               ...
# 2287  http://www.chestnutmedical.com
# 2288         http://www.iguiders.com
# 2289     http://www.solarpower.co.il
# 2290         http://www.purfresh.com  http://info.purfresh.com/PurTalk
# 2291   http://www.insoundmedical.com
#
#                          blog_feed_url twitter_username category_code  \
# 0     http://digitalquarters.net/feed/  BachelrWetpaint           web
# 1       http://blog.geni.com/index.rdf             geni           web
# 2                                           stumbleupon           web
# 3                                                  None           web
# 4            http://www.lala.com/#blog             None   games_video
# ...                                ...              ...           ...
# 2287                                                          biotech
# 2288                                           iGuiders           web
# 2289                                                        cleantech
# 2290                                       Purfresh_Inc     cleantech
# 2291                                                          biotech
#
#       number_of_employees  founded_year  ...  \
# 0                    47.0        2005.0  ...
# 1                    18.0        2006.0  ...
# 2                     NaN        2002.0  ...
# 3                     NaN        2003.0  ...
# 4                     NaN           NaN  ...
# ...                   ...           ...  ...
# 2287                  NaN           NaN  ...
# 2288                  5.0        2008.0  ...
# 2289                  NaN           NaN  ...
# 2290                  NaN        1996.0  ...
# 2291                  NaN           NaN  ...
#
#                                             screenshots  \
# 0     [{'available_sizes': [[[150, 86], 'assets/imag...
# 1                                                    []
# 2     [{'available_sizes': [[[150, 72], 'assets/imag...
# 3                                                    []
# 4     [{'available_sizes': [[[150, 103], 'assets/ima...
# ...                                                 ...
# 2287  [{'available_sizes': [[[150, 98], 'assets/imag...
# 2288  [{'available_sizes': [[[150, 90], 'assets/imag...
# 2289  [{'available_sizes': [[[150, 102], 'assets/ima...
# 2290  [{'available_sizes': [[[150, 91], 'assets/imag...
# 2291  [{'available_sizes': [[[150, 91], 'assets/imag...
#
#                                          external_links  partners  \
# 0     [{'external_url': 'http://www.geekwire.com/201...        []
# 1                                                    []        []
# 2     [{'external_url': 'http://www.facebook.com/Stu...        []
# 3                                                    []        []
# 4                                                    []        []
# ...                                                 ...       ...
# 2287                                                 []        []
# 2288                                                 []        []
# 2289                                                 []        []
# 2290                                                 []        []
# 2291                                                 []        []
#
#      deadpooled_month deadpooled_day deadpooled_url   ipo            City  \
# 0                 NaN            NaN            NaN   NaN         Seattle
# 1                 NaN            NaN           None  None  West Hollywood
# 2                 NaN            NaN           None  None   San Francisco
# 3                 NaN            NaN           None  None      Menlo Park
# 4                 NaN            NaN           None  None       Palo Alto
# ...               ...            ...            ...   ...             ...
# 2287              NaN            NaN           None  None      Menlo Park
# 2288              NaN            NaN           None  None       Beachwood
# 2289              NaN            NaN           None  None
# 2290              NaN            NaN           None  None      Menlo Park
# 2291              NaN            NaN           None  None          Newark
#
#      Country Code Zip Code
# 0             USA    98104
# 1             USA    90069
# 2             USA
# 3             USA     None
# 4             USA    94301
# ...           ...      ...
# 2287          USA    94025
# 2288          USA    44122
# 2289          ISR    42815
# 2290          USA    94025
# 2291          USA    94560
#
# [2292 rows x 44 columns]

# %%
zip_code_in_usa = df_1[(df_1["Country Code"] == "USA") & (df_1["Zip Code"] != "")]
zip_code_counts = zip_code_in_usa["Zip Code"].value_counts().reset_index()
zip_code_counts.columns = ["Zip code", "Count"]
zip_code_counts
# Counts the repetition of the zip codes in USA.
# Out:
#     Zip code  Count
# 0      94105     40
# 1      94107     39
# 2      94085     29
# 3      94043     28
# 4      95054     26
# ..       ...    ...
# 632    20815      1
# 633    55330      1
# 634    95630      1
# 635    94024      1
# 636    44122      1
#
# [637 rows x 2 columns]

# %%
top_10_zip_code_usa = zip_code_counts.head(10)

plt.bar(top_10_zip_code_usa["Zip code"], top_10_zip_code_usa["Count"])
plt.xticks(rotation=45) 
plt.title("Top 10 Zip code in Tech")
plt.savefig('Top 10 zip code in Tech.jpg', format='jpg')
plt.show()
# Shows the top 10 zip codes in USA (with more appearance in the dataset) in a bar plot.
